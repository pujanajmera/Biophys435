# %%
# %%capture
# %tensorflow_version 1

# %% [markdown]
# ## **Install rdkit and deepchem**

# %%
# !apt-get -qq install -y python-rdkit librdkit1 rdkit-data

# %%
# !pip install -q joblib pandas sklearn tensorflow pillow deepchem

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score
from time import time
from scipy.stats import randint as sp_randint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report
import random

import pandas as pd
import io
import requests
import warnings

import deepchem as dc
import deepchem.models.tensorgraph.layers as layers
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Conv1D, MaxPooling1D, Flatten

warnings.filterwarnings("ignore")

# %%
# Global variable 
NUMBER_CHEMICAL_SHIFT_TYPE = 19

def get_cs_all(cs_all, id = "2KOC"):
  '''    
    This function gets chemical shifts for a particular RNA. 
    Assumes each RNA has a unique id  
  '''
  return(cs_all[(cs_all.id == id)])

def get_cs_residues(cs_i, resid, dummy = 0):
  '''    
    This function return an array containing the chemical shifts for a particular residues in an RNA.    
  '''
  cs_tmp = cs_i[(cs_i.resid == resid)].drop(['id', 'resid', 'resname', 'stacking'], axis=1)
  info_tmp = cs_i[(cs_i.resid == resid)]
  if (cs_tmp.shape[0] != 1):
     return(dummy*np.ones(shape=(1, NUMBER_CHEMICAL_SHIFT_TYPE)))
  else:
     return(cs_tmp.values)
    
def get_resnames(cs_i, resid, dummy = "UNK"):
  '''    
    This function returns the residue name for specified residue (resid)
  '''
  cs_tmp = cs_i[(cs_i.resid == resid)]  
  if (cs_tmp.shape[0] != 1):
     return(dummy)
  else:
     return(cs_tmp['resname'].values[0])

def get_cs_features(cs_i, resid, neighbors=1):
  '''    
  This function chemical shifts and resnames for residue (resid) and its neighbors        

  '''
  cs = []
  resnames = []
  for i in range(resid-neighbors, resid+neighbors+1):
    cs.append(get_cs_residues(cs_i, i))
    resnames.append(get_resnames(cs_i, i))
  return(resnames, np.array(cs))

def get_columns_names(neighbors = 3, chemical_shift_types = 19):
  '''
    
    Helper function that writes out the required column names
    
  '''

  columns = ['id', 'resname', 'resid', 'Stacking']
  for i in range(0, neighbors*chemical_shift_types):
    columns.append(i)
  return(columns)

def write_out_resname(neighbors=1):
  '''
  
    Helper function that writes out the column names associated resnames for a given residue and its neighbors
    
  '''  
  colnames = []
  for i in range(1-neighbors-1, neighbors+1):
    if i < 0: 
      colnames.append('R%s'%i)
    elif i > 0: 
      colnames.append('R+%s'%i)
    else: 
      colnames.append('R')
  return(colnames)    


def get_cs_features_rna(cs, neighbors=1, retain = ['id', 'stacking', 'resid']):
  '''    
    This function generates the complete required data frame an RNA    
  '''
  all_features = []
  all_resnames = []
  for resid in cs['resid'].unique():
    resnames, features = get_cs_features(cs, resid, neighbors)
    all_features.append(features.flatten())
    all_resnames.append(resnames)

  all_resnames = pd.DataFrame(all_resnames, dtype='object', columns = write_out_resname(neighbors))
  all_features = pd.DataFrame(all_features, dtype='object')
  info = pd.DataFrame(cs[retain].values, dtype='object', columns = retain)
  return(pd.concat([info, all_resnames, all_features], axis=1))

def get_cs_features_rna_all(cs, neighbors = 2):  
  '''    
    This [should] function generate a pandas dataframe containing training data for all RNAs
    Each row in the data frame should contain the class and chemical shifts for given residue and neighbors in a given RNA.
    Use the function above to write function
    
  '''  
  # Start: your code
  ids = cs['id'].unique()
  for i,id in enumerate(ids):
    if i == 0:
      cs_new = get_cs_features_rna(get_cs_all(cs, id), neighbors)
    else:
      cs_new = cs_new.append(get_cs_features_rna(get_cs_all(cs, id), neighbors), sort = False)        
  # End: your code
  return(cs_new)

def create_training_testing(cs, leave_out = "2KOC", target_name = 'stacking', neighbors = 2, drop_names = ['id', 'stacking', 'resid']):
  '''    
    This function creates a training and testing set using leave one out    
  '''
  
  # drop extraneous data  
  drop_names = drop_names + list(write_out_resname(neighbors))  
  
  # does not contain leave_out
  train = cs[(cs.id != leave_out)]
  trainX = train.drop(drop_names, axis=1)
  trainy = train[target_name]
 
  # only contains leave_out
  test = cs[(cs.id == leave_out)]
  testX = test.drop(drop_names, axis=1)
  testy = test[target_name]
  
  # return training and testing data
  return(trainX.values, trainy.values, testX.values, testy.values)

# %%
#Can put data link here:
url="https://drive.google.com/uc?id=1e-SHtWDtg4mD_th3_4Jmq9r1iiQC32wT"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')), sep = ' ')
my_list = c['id'].tolist()
unique_rnas = []
for values in my_list:
  if values not in unique_rnas:
    unique_rnas.append(values)

#stack (1) and non-stack (0)
c = c.drop(columns = ['Unnamed: 0','base_pairing','orientation','sugar_puckering','pseudoknot'])

c = c.replace('stack',1).replace('non-stack',0)

# %%
#Due to keras not having f1 score, recall, and precision built in, it must be defined. Use keras backend for shortening code
from keras import backend as K

#Define recall by the ratio of true positive to possible positives. k.epsilon is a fuzzy constant used to prevent dividing by 0
def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

#Define precision as the ratio of true positives to predicted positives
def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

#Define f1 score as the ratio of the product to the sum of precision and recall, scaled by 2
def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
#Defining a function (ODC = One Dimensional Convolution)
def ODC(rnaid, n, cs_all):
  id = rnaid
  trainX, trainy, testX, testy = create_training_testing(cs_all, leave_out = id, neighbors = n)
  scaler = StandardScaler()
  scaler.fit(trainX)
  trainX_scaled = scaler.transform(trainX)
  testX_scaled = scaler.transform(testX)

  #The data needs to have its dimensions expanded in order to be put into the 1d convolution
  trainX = np.expand_dims(trainX, axis=2)
  testX = np.expand_dims(testX, axis=2)

  #Creating each layer. Only using one conv1d layer because the vector is small and the patterns may not be relevant due to arbitrary ordering of chemical shifts
  model = Sequential()
  model.add(Conv1D(filters=32, kernel_size=5, activation='relu', input_shape=(trainX.shape[1],trainX.shape[2])))
  model.add(Dropout(0.2))
  model.add(Flatten())
  model.add(Dense(100, activation='relu'))
  model.add(Dense(50, activation='relu'))
  model.add(Dense(trainX.shape[2], activation='softmax'))

  #Compile the model, and define an appropriate loss function for binary classification, and define metrics using previous functions
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', f1_m,precision_m, recall_m])

  #Number of epochs set to 5 due to quick convergence in graph convolution of a relatively short input vector
  model.fit(trainX, trainy, epochs=3)
  accuracy = model.evaluate(testX, testy)

  #Just return f1 score
  return accuracy[2]

# %%
#Run for neighbor number = 1, creating full dataset of RNAS and neighbor chemical shifts

n = 1
cs_all = get_cs_features_rna_all(c, n)
data_list = []
for rna in unique_rnas:
  data_list.append(ODC(rna, n, cs_all))

#Take the average of all the f1 scores
mean_score = sum(data_list)/len(data_list)
mean_score
# Out:
# Epoch 1/3
# 3024/3024 [==============================] - 4s 1ms/step - loss: 1.1885 - acc: 0.8056 - f1_m: 0.8711 - precision_m: 0.8393 - recall_m: 0.9133
# Epoch 2/3
# 3024/3024 [==============================] - 1s 261us/step - loss: 0.4348 - acc: 0.8578 - f1_m: 0.9212 - precision_m: 0.8694 - recall_m: 0.9831
# Epoch 3/3
# 3024/3024 [==============================] - 1s 257us/step - loss: 0.4412 - acc: 0.8614 - f1_m: 0.9238 - precision_m: 0.8702 - recall_m: 0.9889
# 44/44 [==============================] - 1s 30ms/step
# Epoch 1/3
# 3038/3038 [==============================] - 4s 1ms/step - loss: 2.1073 - acc: 0.8644 - f1_m: 0.9253 - precision_m: 0.8676 - recall_m: 0.9945
# Epoch 2/3
# 3038/3038 [==============================] - 1s 263us/step - loss: 2.1201 - acc: 0.8670 - f1_m: 0.9278 - precision_m: 0.8670 - recall_m: 1.0000
# Epoch 3/3
# 3038/3038 [==============================] - 1s 268us/step - loss: 2.1201 - acc: 0.8670 - f1_m: 0.9277 - precision_m: 0.8670 - recall_m: 1.0000
# 30/30 [==============================] - 1s 45ms/step
# Epoch 1/3
# 3037/3037 [==============================] - 4s 1ms/step - loss: 2.0998 - acc: 0.8683 - f1_m: 0.9286 - precision_m: 0.8683 - recall_m: 1.0000
# Epoch 2/3
# 3037/3037 [==============================] - 1s 243us/step - loss: 2.0998 - acc: 0.8683 - f1_m: 0.9282 - precision_m: 0.8683 - recall_m: 1.0000
# Epoch 3/3
# 3037/3037 [==============================] - 1s 261us/step - loss: 2.0998 - acc: 0.8683 - f1_m: 0.9283 - precision_m: 0.8683 - recall_m: 1.0000
# 31/31 [==============================] - 1s 46ms/step
# Epoch 1/3
# 3051/3051 [==============================] - 4s 1ms/step - loss: 2.2120 - acc: 0.8584 - f1_m: 0.9176 - precision_m: 0.8574 - recall_m: 0.9895
# Epoch 2/3
# 3051/3051 [==============================] - 1s 256us/step - loss: 2.1215 - acc: 0.8669 - f1_m: 0.9278 - precision_m: 0.8669 - recall_m: 1.0000
# Epoch 3/3
# 3051/3051 [==============================] - 1s 253us/step - loss: 2.1215 - acc: 0.8669 - f1_m: 0.9274 - precision_m: 0.8669 - recall_m: 1.0000
# 17/17 [==============================] - 1s 84ms/step
# Epoch 1/3
# 3039/3039 [==============================] - 4s 1ms/step - loss: 2.1393 - acc: 0.8628 - f1_m: 0.9244 - precision_m: 0.8659 - recall_m: 0.9951
# Epoch 2/3
# 3039/3039 [==============================] - 1s 259us/step - loss: 2.1403 - acc: 0.8657 - f1_m: 0.9269 - precision_m: 0.8657 - recall_m: 1.0000
# Epoch 3/3
# 3039/3039 [==============================] - 1s 255us/step - loss: 2.1403 - acc: 0.8657 - f1_m: 0.9270 - precision_m: 0.8657 - recall_m: 1.0000
# 29/29 [==============================] - 1s 50ms/step
# Epoch 1/3
# 3044/3044 [==============================] - 5s 2ms/step - loss: 2.1333 - acc: 0.8617 - f1_m: 0.9234 - precision_m: 0.8653 - recall_m: 0.9938
# Epoch 2/3
# 3044/3044 [==============================] - 1s 255us/step - loss: 2.1211 - acc: 0.8670 - f1_m: 0.9275 - precision_m: 0.8670 - recall_m: 1.0000
# Epoch 3/3
# 3044/3044 [==============================] - 1s 256us/step - loss: 2.1211 - acc: 0.8670 - f1_m: 0.9276 - precision_m: 0.8670 - recall_m: 1.0000
# 24/24 [==============================] - 2s 63ms/step
# Epoch 1/3
# 3038/3038 [==============================] - 5s 2ms/step - loss: 2.1780 - acc: 0.8598 - f1_m: 0.9201 - precision_m: 0.8656 - recall_m: 0.9910
# Epoch 2/3
# 3038/3038 [==============================] - 1s 258us/step - loss: 2.1358 - acc: 0.8660 - f1_m: 0.9268 - precision_m: 0.8660 - recall_m: 1.0000
# Epoch 3/3
# 3038/3038 [==============================] - 1s 264us/step - loss: 2.1358 - acc: 0.8660 - f1_m: 0.9269 - precision_m: 0.8660 - recall_m: 1.0000
# 30/30 [==============================] - 2s 52ms/step
# Epoch 1/3
# 3038/3038 [==============================] - 5s 2ms/step - loss: 2.1354 - acc: 0.8621 - f1_m: 0.9235 - precision_m: 0.8672 - recall_m: 0.9938
# Epoch 2/3
# 3038/3038 [==============================] - 1s 278us/step - loss: 2.1201 - acc: 0.8670 - f1_m: 0.9273 - precision_m: 0.8670 - recall_m: 1.0000
# Epoch 3/3
# 3038/3038 [==============================] - 1s 270us/step - loss: 2.1201 - acc: 0.8670 - f1_m: 0.9277 - precision_m: 0.8670 - recall_m: 1.0000
# 30/30 [==============================] - 2s 55ms/step
# Epoch 1/3
# 3038/3038 [==============================] - 5s 2ms/step - loss: 2.2224 - acc: 0.8598 - f1_m: 0.9187 - precision_m: 0.8631 - recall_m: 0.9899
# Epoch 2/3
# 3038/3038 [==============================] - 1s 281us/step - loss: 2.1305 - acc: 0.8664 - f1_m: 0.9273 - precision_m: 0.8664 - recall_m: 1.0000
# Epoch 3/3
# 3038/3038 [==============================] - 1s 273us/step - loss: 2.1305 - acc: 0.8664 - f1_m: 0.9274 - precision_m: 0.8664 - recall_m: 1.0000
# 30/30 [==============================] - 2s 56ms/step
# Epoch 1/3
# 3044/3044 [==============================] - 5s 2ms/step - loss: 2.1036 - acc: 0.8637 - f1_m: 0.9232 - precision_m: 0.8676 - recall_m: 0.9926
# Epoch 2/3
# 3044/3044 [==============================] - 1s 269us/step - loss: 2.1159 - acc: 0.8673 - f1_m: 0.9279 - precision_m: 0.8673 - recall_m: 1.0000
# Epoch 3/3
# 3044/3044 [==============================] - 1s 268us/step - loss: 2.1159 - acc: 0.8673 - f1_m: 0.9277 - precision_m: 0.8673 - recall_m: 1.0000
# 24/24 [==============================] - 2s 73ms/step
# Epoch 1/3
# 3045/3045 [==============================] - 5s 2ms/step - loss: 2.1773 - acc: 0.8588 - f1_m: 0.9182 - precision_m: 0.8677 - recall_m: 0.9899
# Epoch 2/3
# 3045/3045 [==============================] - 1s 269us/step - loss: 2.1309 - acc: 0.8663 - f1_m: 0.9273 - precision_m: 0.8663 - recall_m: 1.0000
# Epoch 3/3
# 3045/3045 [==============================] - 1s 259us/step - loss: 2.1309 - acc: 0.8663 - f1_m: 0.9276 - precision_m: 0.8663 - recall_m: 1.0000
# 23/23 [==============================] - 2s 75ms/step
# Epoch 1/3
# 3046/3046 [==============================] - 5s 2ms/step - loss: 2.1861 - acc: 0.8592 - f1_m: 0.9177 - precision_m: 0.8575 - recall_m: 0.9895
# Epoch 2/3
# 3046/3046 [==============================] - 1s 288us/step - loss: 2.1302 - acc: 0.8664 - f1_m: 0.9273 - precision_m: 0.8664 - recall_m: 1.0000
# Epoch 3/3
# 3046/3046 [==============================] - 1s 281us/step - loss: 2.1302 - acc: 0.8664 - f1_m: 0.9277 - precision_m: 0.8664 - recall_m: 1.0000
# 22/22 [==============================] - 2s 82ms/step
# Epoch 1/3
# 3053/3053 [==============================] - 6s 2ms/step - loss: 2.0942 - acc: 0.8664 - f1_m: 0.9272 - precision_m: 0.8684 - recall_m: 0.9975
# Epoch 2/3
# 3053/3053 [==============================] - 1s 276us/step - loss: 2.0992 - acc: 0.8683 - f1_m: 0.9285 - precision_m: 0.8683 - recall_m: 1.0000
# Epoch 3/3
# 3053/3053 [==============================] - 1s 275us/step - loss: 2.0992 - acc: 0.8683 - f1_m: 0.9282 - precision_m: 0.8683 - recall_m: 1.0000
# 15/15 [==============================] - 2s 124ms/step
# Epoch 1/3
# 3034/3034 [==============================] - 5s 2ms/step - loss: 2.1361 - acc: 0.8635 - f1_m: 0.9253 - precision_m: 0.8664 - recall_m: 0.9968
# Epoch 2/3
# 3034/3034 [==============================] - 1s 265us/step - loss: 2.1334 - acc: 0.8662 - f1_m: 0.9271 - precision_m: 0.8662 - recall_m: 1.0000
# Epoch 3/3
# 3034/3034 [==============================] - 1s 268us/step - loss: 2.1334 - acc: 0.8662 - f1_m: 0.9269 - precision_m: 0.8662 - recall_m: 1.0000
# 34/34 [==============================] - 2s 55ms/step
# Epoch 1/3
# 3034/3034 [==============================] - 6s 2ms/step - loss: 2.1152 - acc: 0.8655 - f1_m: 0.9265 - precision_m: 0.8673 - recall_m: 0.9979
# Epoch 2/3
# 3034/3034 [==============================] - 1s 287us/step - loss: 2.1123 - acc: 0.8675 - f1_m: 0.9281 - precision_m: 0.8675 - recall_m: 1.0000
# Epoch 3/3
# 3034/3034 [==============================] - 1s 290us/step - loss: 2.1123 - acc: 0.8675 - f1_m: 0.9280 - precision_m: 0.8675 - recall_m: 1.0000
# 34/34 [==============================] - 2s 56ms/step
# Epoch 1/3
# 3039/3039 [==============================] - 6s 2ms/step - loss: 2.1810 - acc: 0.8602 - f1_m: 0.9202 - precision_m: 0.8677 - recall_m: 0.9910
# Epoch 2/3
# 3039/3039 [==============================] - 1s 282us/step - loss: 2.1351 - acc: 0.8661 - f1_m: 0.9271 - precision_m: 0.8661 - recall_m: 1.0000
# Epoch 3/3
# 3039/3039 [==============================] - 1s 284us/step - loss: 2.1351 - acc: 0.8661 - f1_m: 0.9272 - precision_m: 0.8661 - recall_m: 1.0000
# 29/29 [==============================] - 2s 68ms/step
# Epoch 1/3
# 3044/3044 [==============================] - 6s 2ms/step - loss: 0.8225 - acc: 0.8091 - f1_m: 0.8842 - precision_m: 0.8621 - recall_m: 0.9199
# Epoch 2/3
# 3044/3044 [==============================] - 1s 286us/step - loss: 0.4501 - acc: 0.8505 - f1_m: 0.9168 - precision_m: 0.8692 - recall_m: 0.9744
# Epoch 3/3
# 3044/3044 [==============================] - 1s 290us/step - loss: 0.4480 - acc: 0.8548 - f1_m: 0.9193 - precision_m: 0.8687 - recall_m: 0.9806
# 24/24 [==============================] - 2s 85ms/step
# Epoch 1/3
# 3044/3044 [==============================] - 6s 2ms/step - loss: 2.1905 - acc: 0.8610 - f1_m: 0.9184 - precision_m: 0.8594 - recall_m: 0.9891
# Epoch 2/3
# 3044/3044 [==============================] - 1s 278us/step - loss: 2.1054 - acc: 0.8679 - f1_m: 0.9280 - precision_m: 0.8679 - recall_m: 1.0000
# Epoch 3/3
# 3044/3044 [==============================] - 1s 281us/step - loss: 2.1054 - acc: 0.8679 - f1_m: 0.9283 - precision_m: 0.8679 - recall_m: 1.0000
# 24/24 [==============================] - 2s 85ms/step
# Epoch 1/3
# 3049/3049 [==============================] - 6s 2ms/step - loss: 2.1065 - acc: 0.8649 - f1_m: 0.9248 - precision_m: 0.8689 - recall_m: 0.9941
# Epoch 2/3
# 3049/3049 [==============================] - 1s 284us/step - loss: 2.1124 - acc: 0.8675 - f1_m: 0.9280 - precision_m: 0.8675 - recall_m: 1.0000
# Epoch 3/3
# 3049/3049 [==============================] - 1s 291us/step - loss: 2.1124 - acc: 0.8675 - f1_m: 0.9279 - precision_m: 0.8675 - recall_m: 1.0000
# 19/19 [==============================] - 2s 110ms/step
# Epoch 1/3
# 3036/3036 [==============================] - 6s 2ms/step - loss: 2.1467 - acc: 0.8613 - f1_m: 0.9234 - precision_m: 0.8666 - recall_m: 0.9944
# Epoch 2/3
# 3036/3036 [==============================] - 1s 295us/step - loss: 2.1372 - acc: 0.8659 - f1_m: 0.9271 - precision_m: 0.8659 - recall_m: 1.0000
# Epoch 3/3
# 3036/3036 [==============================] - 1s 286us/step - loss: 2.1372 - acc: 0.8659 - f1_m: 0.9271 - precision_m: 0.8659 - recall_m: 1.0000
# 32/32 [==============================] - 2s 67ms/step
# Epoch 1/3
# 3021/3021 [==============================] - 6s 2ms/step - loss: 2.1215 - acc: 0.8623 - f1_m: 0.9237 - precision_m: 0.8660 - recall_m: 0.9933
# Epoch 2/3
# 3021/3021 [==============================] - 1s 291us/step - loss: 2.1056 - acc: 0.8679 - f1_m: 0.9284 - precision_m: 0.8679 - recall_m: 1.0000
# Epoch 3/3
# 3021/3021 [==============================] - 1s 299us/step - loss: 2.1056 - acc: 0.8679 - f1_m: 0.9282 - precision_m: 0.8679 - recall_m: 1.0000
# 47/47 [==============================] - 2s 47ms/step
# Epoch 1/3
# 3041/3041 [==============================] - 6s 2ms/step - loss: 2.8660 - acc: 0.8165 - f1_m: 0.8642 - precision_m: 0.8233 - recall_m: 0.9288
# Epoch 2/3
# 3041/3041 [==============================] - 1s 277us/step - loss: 2.1337 - acc: 0.8662 - f1_m: 0.9271 - precision_m: 0.8662 - recall_m: 1.0000
# Epoch 3/3
# 3041/3041 [==============================] - 1s 279us/step - loss: 2.1337 - acc: 0.8662 - f1_m: 0.9274 - precision_m: 0.8662 - recall_m: 1.0000
# 27/27 [==============================] - 2s 82ms/step
# Epoch 1/3
# 3023/3023 [==============================] - 7s 2ms/step - loss: 2.2765 - acc: 0.8564 - f1_m: 0.9160 - precision_m: 0.8554 - recall_m: 0.9894
# Epoch 2/3
# 3023/3023 [==============================] - 1s 323us/step - loss: 2.1517 - acc: 0.8650 - f1_m: 0.9265 - precision_m: 0.8650 - recall_m: 1.0000
# Epoch 3/3
# 3023/3023 [==============================] - 1s 307us/step - loss: 2.1517 - acc: 0.8650 - f1_m: 0.9262 - precision_m: 0.8650 - recall_m: 1.0000
# 45/45 [==============================] - 2s 52ms/step
# Epoch 1/3
# 3050/3050 [==============================] - 7s 2ms/step - loss: 2.1947 - acc: 0.8580 - f1_m: 0.9187 - precision_m: 0.8672 - recall_m: 0.9902
# Epoch 2/3
# 3050/3050 [==============================] - 1s 285us/step - loss: 2.1274 - acc: 0.8666 - f1_m: 0.9277 - precision_m: 0.8666 - recall_m: 1.0000
# Epoch 3/3
# 3050/3050 [==============================] - 1s 280us/step - loss: 2.1274 - acc: 0.8666 - f1_m: 0.9276 - precision_m: 0.8666 - recall_m: 1.0000
# 18/18 [==============================] - 2s 128ms/step
# Epoch 1/3
# 3027/3027 [==============================] - 7s 2ms/step - loss: 2.3010 - acc: 0.8523 - f1_m: 0.9112 - precision_m: 0.8548 - recall_m: 0.9815
# Epoch 2/3
# 3027/3027 [==============================] - 1s 287us/step - loss: 2.1488 - acc: 0.8652 - f1_m: 0.9264 - precision_m: 0.8652 - recall_m: 1.0000
# Epoch 3/3
# 3027/3027 [==============================] - 1s 297us/step - loss: 2.1488 - acc: 0.8652 - f1_m: 0.9266 - precision_m: 0.8652 - recall_m: 1.0000
# 41/41 [==============================] - 2s 57ms/step
# Epoch 1/3
# 3040/3040 [==============================] - 7s 2ms/step - loss: 2.1344 - acc: 0.8661 - f1_m: 0.9272 - precision_m: 0.8661 - recall_m: 1.0000
# Epoch 2/3
# 3040/3040 [==============================] - 1s 316us/step - loss: 2.1344 - acc: 0.8661 - f1_m: 0.9274 - precision_m: 0.8661 - recall_m: 1.0000
# Epoch 3/3
# 3040/3040 [==============================] - 1s 312us/step - loss: 2.1344 - acc: 0.8661 - f1_m: 0.9271 - precision_m: 0.8661 - recall_m: 1.0000
# 28/28 [==============================] - 2s 85ms/step
# Epoch 1/3
# 3040/3040 [==============================] - 7s 2ms/step - loss: 2.1781 - acc: 0.8599 - f1_m: 0.9173 - precision_m: 0.8581 - recall_m: 0.9880
# Epoch 2/3
# 3040/3040 [==============================] - 1s 290us/step - loss: 2.1396 - acc: 0.8658 - f1_m: 0.9269 - precision_m: 0.8658 - recall_m: 1.0000
# Epoch 3/3
# 3040/3040 [==============================] - 1s 286us/step - loss: 2.1396 - acc: 0.8658 - f1_m: 0.9269 - precision_m: 0.8658 - recall_m: 1.0000
# 28/28 [==============================] - 2s 88ms/step
# Epoch 1/3
# 3056/3056 [==============================] - 7s 2ms/step - loss: 2.1077 - acc: 0.8639 - f1_m: 0.9254 - precision_m: 0.8668 - recall_m: 0.9956
# Epoch 2/3
# 3056/3056 [==============================] - 1s 305us/step - loss: 2.1284 - acc: 0.8665 - f1_m: 0.9274 - precision_m: 0.8665 - recall_m: 1.0000
# Epoch 3/3
# 3056/3056 [==============================] - 1s 293us/step - loss: 2.1284 - acc: 0.8665 - f1_m: 0.9273 - precision_m: 0.8665 - recall_m: 1.0000
# 12/12 [==============================] - 2s 198ms/step
# Epoch 1/3
# 3032/3032 [==============================] - 7s 2ms/step - loss: 2.1797 - acc: 0.8608 - f1_m: 0.9205 - precision_m: 0.8681 - recall_m: 0.9911
# Epoch 2/3
# 3032/3032 [==============================] - 1s 281us/step - loss: 2.1348 - acc: 0.8661 - f1_m: 0.9268 - precision_m: 0.8661 - recall_m: 1.0000
# Epoch 3/3
# 3032/3032 [==============================] - 1s 279us/step - loss: 2.1348 - acc: 0.8661 - f1_m: 0.9270 - precision_m: 0.8661 - recall_m: 1.0000
# 36/36 [==============================] - 2s 68ms/step
# Epoch 1/3
# 3050/3050 [==============================] - 7s 2ms/step - loss: 2.1558 - acc: 0.8613 - f1_m: 0.9192 - precision_m: 0.8692 - recall_m: 0.9899
# Epoch 2/3
# 3050/3050 [==============================] - 1s 295us/step - loss: 2.1222 - acc: 0.8669 - f1_m: 0.9274 - precision_m: 0.8669 - recall_m: 1.0000
# Epoch 3/3
# 3050/3050 [==============================] - 1s 289us/step - loss: 2.1222 - acc: 0.8669 - f1_m: 0.9274 - precision_m: 0.8669 - recall_m: 1.0000
# 18/18 [==============================] - 2s 139ms/step
# Epoch 1/3
# 3051/3051 [==============================] - 7s 2ms/step - loss: 0.7621 - acc: 0.8204 - f1_m: 0.8881 - precision_m: 0.8582 - recall_m: 0.9307
# Epoch 2/3
# 3051/3051 [==============================] - 1s 292us/step - loss: 0.4460 - acc: 0.8558 - f1_m: 0.9206 - precision_m: 0.8694 - recall_m: 0.9819
# Epoch 3/3
# 3051/3051 [==============================] - 1s 299us/step - loss: 0.4087 - acc: 0.8643 - f1_m: 0.9259 - precision_m: 0.8676 - recall_m: 0.9955
# 17/17 [==============================] - 3s 149ms/step
# Epoch 1/3
# 3039/3039 [==============================] - 7s 2ms/step - loss: 2.1465 - acc: 0.8618 - f1_m: 0.9221 - precision_m: 0.8669 - recall_m: 0.9920
# Epoch 2/3
# 3039/3039 [==============================] - 1s 294us/step - loss: 2.1351 - acc: 0.8661 - f1_m: 0.9270 - precision_m: 0.8661 - recall_m: 1.0000
# Epoch 3/3
# 3039/3039 [==============================] - 1s 297us/step - loss: 2.1351 - acc: 0.8661 - f1_m: 0.9271 - precision_m: 0.8661 - recall_m: 1.0000
# 29/29 [==============================] - 3s 90ms/step
# Epoch 1/3
# 3046/3046 [==============================] - 7s 2ms/step - loss: 2.1180 - acc: 0.8621 - f1_m: 0.9233 - precision_m: 0.8664 - recall_m: 0.9930
# Epoch 2/3
# 3046/3046 [==============================] - 1s 299us/step - loss: 2.1145 - acc: 0.8674 - f1_m: 0.9279 - precision_m: 0.8674 - recall_m: 1.0000
# Epoch 3/3
# 3046/3046 [==============================] - 1s 291us/step - loss: 2.1145 - acc: 0.8674 - f1_m: 0.9278 - precision_m: 0.8674 - recall_m: 1.0000
# 22/22 [==============================] - 3s 122ms/step
# Epoch 1/3
# 3046/3046 [==============================] - 8s 3ms/step - loss: 2.1593 - acc: 0.8608 - f1_m: 0.9211 - precision_m: 0.8665 - recall_m: 0.9918
# Epoch 2/3
# 3046/3046 [==============================] - 1s 312us/step - loss: 2.1354 - acc: 0.8661 - f1_m: 0.9269 - precision_m: 0.8661 - recall_m: 1.0000
# Epoch 3/3
# 3046/3046 [==============================] - 1s 307us/step - loss: 2.1354 - acc: 0.8661 - f1_m: 0.9272 - precision_m: 0.8661 - recall_m: 1.0000
# 22/22 [==============================] - 3s 124ms/step
# Epoch 1/3
# 3044/3044 [==============================] - 8s 3ms/step - loss: 0.8254 - acc: 0.8203 - f1_m: 0.8885 - precision_m: 0.8602 - recall_m: 0.9365
# Epoch 2/3
# 3044/3044 [==============================] - 1s 324us/step - loss: 0.4550 - acc: 0.8564 - f1_m: 0.9212 - precision_m: 0.8674 - recall_m: 0.9858
# Epoch 3/3
# 3044/3044 [==============================] - 1s 318us/step - loss: 0.4420 - acc: 0.8604 - f1_m: 0.9236 - precision_m: 0.8664 - recall_m: 0.9922
# 24/24 [==============================] - 3s 116ms/step
# Epoch 1/3
# 3044/3044 [==============================] - 8s 3ms/step - loss: 2.1682 - acc: 0.8532 - f1_m: 0.9142 - precision_m: 0.8691 - recall_m: 0.9810
# Epoch 2/3
# 3044/3044 [==============================] - 1s 310us/step - loss: 2.1263 - acc: 0.8666 - f1_m: 0.9273 - precision_m: 0.8666 - recall_m: 1.0000
# Epoch 3/3
# 3044/3044 [==============================] - 1s 318us/step - loss: 2.1263 - acc: 0.8666 - f1_m: 0.9273 - precision_m: 0.8666 - recall_m: 1.0000
# 24/24 [==============================] - 3s 118ms/step
# Epoch 1/3
# 3054/3054 [==============================] - 8s 3ms/step - loss: 2.1410 - acc: 0.8592 - f1_m: 0.9178 - precision_m: 0.8579 - recall_m: 0.9895
# Epoch 2/3
# 3054/3054 [==============================] - 1s 302us/step - loss: 2.1246 - acc: 0.8667 - f1_m: 0.9272 - precision_m: 0.8667 - recall_m: 1.0000
# Epoch 3/3
# 3054/3054 [==============================] - 1s 313us/step - loss: 2.1246 - acc: 0.8667 - f1_m: 0.9276 - precision_m: 0.8667 - recall_m: 1.0000
# 14/14 [==============================] - 3s 205ms/step
# Epoch 1/3
# 3041/3041 [==============================] - 8s 3ms/step - loss: 1.5162 - acc: 0.8182 - f1_m: 0.8883 - precision_m: 0.8620 - recall_m: 0.9330
# Epoch 2/3
# 3041/3041 [==============================] - 1s 313us/step - loss: 0.4617 - acc: 0.8500 - f1_m: 0.9170 - precision_m: 0.8675 - recall_m: 0.9759
# Epoch 3/3
# 3041/3041 [==============================] - 1s 311us/step - loss: 0.4184 - acc: 0.8625 - f1_m: 0.9250 - precision_m: 0.8676 - recall_m: 0.9934
# 27/27 [==============================] - 3s 108ms/step
# Epoch 1/3
# 3013/3013 [==============================] - 8s 3ms/step - loss: 2.1313 - acc: 0.8626 - f1_m: 0.9236 - precision_m: 0.8679 - recall_m: 0.9932
# Epoch 2/3
# 3013/3013 [==============================] - 1s 322us/step - loss: 2.1112 - acc: 0.8676 - f1_m: 0.9279 - precision_m: 0.8676 - recall_m: 1.0000
# Epoch 3/3
# 3013/3013 [==============================] - 1s 334us/step - loss: 2.1112 - acc: 0.8676 - f1_m: 0.9280 - precision_m: 0.8676 - recall_m: 1.0000
# 55/55 [==============================] - 3s 55ms/step
# Epoch 1/3
# 3033/3033 [==============================] - 8s 3ms/step - loss: 2.1613 - acc: 0.8602 - f1_m: 0.9208 - precision_m: 0.8651 - recall_m: 0.9914
# Epoch 2/3
# 3033/3033 [==============================] - 1s 313us/step - loss: 2.1288 - acc: 0.8665 - f1_m: 0.9274 - precision_m: 0.8665 - recall_m: 1.0000
# Epoch 3/3
# 3033/3033 [==============================] - 1s 311us/step - loss: 2.1288 - acc: 0.8665 - f1_m: 0.9275 - precision_m: 0.8665 - recall_m: 1.0000
# 35/35 [==============================] - 3s 85ms/step
# Epoch 1/3
# 3042/3042 [==============================] - 8s 3ms/step - loss: 2.1913 - acc: 0.8586 - f1_m: 0.9207 - precision_m: 0.8665 - recall_m: 0.9919
# Epoch 2/3
# 3042/3042 [==============================] - 1s 331us/step - loss: 2.1330 - acc: 0.8662 - f1_m: 0.9274 - precision_m: 0.8662 - recall_m: 1.0000
# Epoch 3/3
# 3042/3042 [==============================] - 1s 322us/step - loss: 2.1330 - acc: 0.8662 - f1_m: 0.9269 - precision_m: 0.8662 - recall_m: 1.0000
# 26/26 [==============================] - 3s 117ms/step
# Epoch 1/3
# 3052/3052 [==============================] - 8s 3ms/step - loss: 2.1050 - acc: 0.8644 - f1_m: 0.9248 - precision_m: 0.8677 - recall_m: 0.9941
# Epoch 2/3
# 3052/3052 [==============================] - 1s 293us/step - loss: 2.1103 - acc: 0.8676 - f1_m: 0.9278 - precision_m: 0.8676 - recall_m: 1.0000
# Epoch 3/3
# 3052/3052 [==============================] - 1s 300us/step - loss: 2.1103 - acc: 0.8676 - f1_m: 0.9280 - precision_m: 0.8676 - recall_m: 1.0000
# 16/16 [==============================] - 3s 187ms/step
# Epoch 1/3
# 3039/3039 [==============================] - 9s 3ms/step - loss: 0.5518 - acc: 0.8295 - f1_m: 0.9027 - precision_m: 0.8675 - recall_m: 0.9488
# Epoch 2/3
# 3039/3039 [==============================] - 1s 309us/step - loss: 0.4240 - acc: 0.8605 - f1_m: 0.9236 - precision_m: 0.8673 - recall_m: 0.9911
# Epoch 3/3
# 3039/3039 [==============================] - 1s 306us/step - loss: 0.3941 - acc: 0.8651 - f1_m: 0.9266 - precision_m: 0.8665 - recall_m: 0.9980
# 29/29 [==============================] - 3s 108ms/step
# Epoch 1/3
# 3051/3051 [==============================] - 9s 3ms/step - loss: 2.1876 - acc: 0.8600 - f1_m: 0.9209 - precision_m: 0.8679 - recall_m: 0.9913
# Epoch 2/3
# 3051/3051 [==============================] - 1s 304us/step - loss: 2.1215 - acc: 0.8669 - f1_m: 0.9276 - precision_m: 0.8669 - recall_m: 1.0000
# Epoch 3/3
# 3051/3051 [==============================] - 1s 321us/step - loss: 2.1215 - acc: 0.8669 - f1_m: 0.9278 - precision_m: 0.8669 - recall_m: 1.0000
# 17/17 [==============================] - 3s 188ms/step
# Epoch 1/3
# 3051/3051 [==============================] - 9s 3ms/step - loss: 2.1311 - acc: 0.8650 - f1_m: 0.9219 - precision_m: 0.8725 - recall_m: 0.9904
# Epoch 2/3
# 3051/3051 [==============================] - 1s 300us/step - loss: 2.0692 - acc: 0.8702 - f1_m: 0.9292 - precision_m: 0.8702 - recall_m: 1.0000
# Epoch 3/3
# 3051/3051 [==============================] - 1s 299us/step - loss: 2.0692 - acc: 0.8702 - f1_m: 0.9293 - precision_m: 0.8702 - recall_m: 1.0000
# 17/17 [==============================] - 3s 186ms/step
# Epoch 1/3
# 3051/3051 [==============================] - 9s 3ms/step - loss: 2.1077 - acc: 0.8643 - f1_m: 0.9255 - precision_m: 0.8692 - recall_m: 0.9948
# Epoch 2/3
# 3051/3051 [==============================] - 1s 310us/step - loss: 2.0953 - acc: 0.8686 - f1_m: 0.9287 - precision_m: 0.8686 - recall_m: 1.0000
# Epoch 3/3
# 3051/3051 [==============================] - 1s 319us/step - loss: 2.0953 - acc: 0.8686 - f1_m: 0.9286 - precision_m: 0.8686 - recall_m: 1.0000
# 17/17 [==============================] - 3s 192ms/step
# Epoch 1/3
# 3051/3051 [==============================] - 9s 3ms/step - loss: 2.0981 - acc: 0.8623 - f1_m: 0.9222 - precision_m: 0.8690 - recall_m: 0.9907
# Epoch 2/3
# 3051/3051 [==============================] - 1s 326us/step - loss: 2.0797 - acc: 0.8696 - f1_m: 0.9293 - precision_m: 0.8696 - recall_m: 1.0000
# Epoch 3/3
# 3051/3051 [==============================] - 1s 310us/step - loss: 2.0797 - acc: 0.8696 - f1_m: 0.9293 - precision_m: 0.8696 - recall_m: 1.0000
# 17/17 [==============================] - 3s 189ms/step
# Epoch 1/3
# 3043/3043 [==============================] - 9s 3ms/step - loss: 2.2237 - acc: 0.8577 - f1_m: 0.9184 - precision_m: 0.8634 - recall_m: 0.9902
# Epoch 2/3
# 3043/3043 [==============================] - 1s 307us/step - loss: 2.1375 - acc: 0.8659 - f1_m: 0.9269 - precision_m: 0.8659 - recall_m: 1.0000
# Epoch 3/3
# 3043/3043 [==============================] - 1s 303us/step - loss: 2.1375 - acc: 0.8659 - f1_m: 0.9269 - precision_m: 0.8659 - recall_m: 1.0000
# 25/25 [==============================] - 3s 135ms/step
# Epoch 1/3
# 3037/3037 [==============================] - 9s 3ms/step - loss: 2.1953 - acc: 0.8584 - f1_m: 0.9192 - precision_m: 0.8670 - recall_m: 0.9906
# Epoch 2/3
# 3037/3037 [==============================] - 1s 317us/step - loss: 2.1365 - acc: 0.8660 - f1_m: 0.9271 - precision_m: 0.8660 - recall_m: 1.0000
# Epoch 3/3
# 3037/3037 [==============================] - 1s 301us/step - loss: 2.1365 - acc: 0.8660 - f1_m: 0.9274 - precision_m: 0.8660 - recall_m: 1.0000
# 31/31 [==============================] - 3s 108ms/step
# Epoch 1/3
# 3031/3031 [==============================] - 9s 3ms/step - loss: 0.6414 - acc: 0.8278 - f1_m: 0.9020 - precision_m: 0.8668 - recall_m: 0.9468
# Epoch 2/3
# 3031/3031 [==============================] - 1s 332us/step - loss: 0.4108 - acc: 0.8651 - f1_m: 0.9266 - precision_m: 0.8669 - recall_m: 0.9973
# Epoch 3/3
# 3031/3031 [==============================] - 1s 324us/step - loss: 0.4141 - acc: 0.8664 - f1_m: 0.9272 - precision_m: 0.8666 - recall_m: 0.9996
# 37/37 [==============================] - 3s 91ms/step
# Epoch 1/3
# 3036/3036 [==============================] - 9s 3ms/step - loss: 2.2307 - acc: 0.8590 - f1_m: 0.9179 - precision_m: 0.8580 - recall_m: 0.9895
# Epoch 2/3
# 3036/3036 [==============================] - 1s 340us/step - loss: 2.1109 - acc: 0.8676 - f1_m: 0.9282 - precision_m: 0.8676 - recall_m: 1.0000
# Epoch 3/3
# 3036/3036 [==============================] - 1s 337us/step - loss: 2.1109 - acc: 0.8676 - f1_m: 0.9277 - precision_m: 0.8676 - recall_m: 1.0000
# 32/32 [==============================] - 3s 106ms/step
# Epoch 1/3
# 3041/3041 [==============================] - 10s 3ms/step - loss: 2.2414 - acc: 0.8543 - f1_m: 0.9103 - precision_m: 0.8604 - recall_m: 0.9794
# Epoch 2/3
# 3041/3041 [==============================] - 1s 326us/step - loss: 2.1232 - acc: 0.8668 - f1_m: 0.9275 - precision_m: 0.8668 - recall_m: 1.0000
# Epoch 3/3
# 3041/3041 [==============================] - 1s 331us/step - loss: 2.1232 - acc: 0.8668 - f1_m: 0.9276 - precision_m: 0.8668 - recall_m: 1.0000
# 27/27 [==============================] - 4s 130ms/step
# Epoch 1/3
# 3044/3044 [==============================] - 10s 3ms/step - loss: 2.2258 - acc: 0.8591 - f1_m: 0.9179 - precision_m: 0.8577 - recall_m: 0.9891
# Epoch 2/3
# 3044/3044 [==============================] - 1s 336us/step - loss: 2.1263 - acc: 0.8666 - f1_m: 0.9273 - precision_m: 0.8666 - recall_m: 1.0000
# Epoch 3/3
# 3044/3044 [==============================] - 1s 336us/step - loss: 2.1263 - acc: 0.8666 - f1_m: 0.9275 - precision_m: 0.8666 - recall_m: 1.0000
# 24/24 [==============================] - 4s 147ms/step
# Epoch 1/3
# 3052/3052 [==============================] - 10s 3ms/step - loss: 2.2168 - acc: 0.8588 - f1_m: 0.9176 - precision_m: 0.8578 - recall_m: 0.9888
# Epoch 2/3
# 3052/3052 [==============================] - 1s 326us/step - loss: 2.1260 - acc: 0.8666 - f1_m: 0.9275 - precision_m: 0.8666 - recall_m: 1.0000
# Epoch 3/3
# 3052/3052 [==============================] - 1s 317us/step - loss: 2.1260 - acc: 0.8666 - f1_m: 0.9274 - precision_m: 0.8666 - recall_m: 1.0000
# 16/16 [==============================] - 4s 221ms/step
# Epoch 1/3
# 3053/3053 [==============================] - 10s 3ms/step - loss: 2.2470 - acc: 0.8569 - f1_m: 0.9170 - precision_m: 0.8568 - recall_m: 0.9888
# Epoch 2/3
# 3053/3053 [==============================] - 1s 331us/step - loss: 2.1305 - acc: 0.8664 - f1_m: 0.9275 - precision_m: 0.8664 - recall_m: 1.0000
# Epoch 3/3
# 3053/3053 [==============================] - 1s 352us/step - loss: 2.1305 - acc: 0.8664 - f1_m: 0.9274 - precision_m: 0.8664 - recall_m: 1.0000
# 15/15 [==============================] - 4s 243ms/step
# Epoch 1/3
# 3034/3034 [==============================] - 10s 3ms/step - loss: 2.2482 - acc: 0.8573 - f1_m: 0.9168 - precision_m: 0.8569 - recall_m: 0.9884
# Epoch 2/3
# 3034/3034 [==============================] - 1s 341us/step - loss: 2.1334 - acc: 0.8662 - f1_m: 0.9272 - precision_m: 0.8662 - recall_m: 1.0000
# Epoch 3/3
# 3034/3034 [==============================] - 1s 320us/step - loss: 2.1334 - acc: 0.8662 - f1_m: 0.9270 - precision_m: 0.8662 - recall_m: 1.0000
# 34/34 [==============================] - 4s 108ms/step
# Epoch 1/3
# 3041/3041 [==============================] - 10s 3ms/step - loss: 2.1042 - acc: 0.8655 - f1_m: 0.9266 - precision_m: 0.8679 - recall_m: 0.9965
# Epoch 2/3
# 3041/3041 [==============================] - 1s 344us/step - loss: 2.1022 - acc: 0.8681 - f1_m: 0.9284 - precision_m: 0.8681 - recall_m: 1.0000
# Epoch 3/3
# 3041/3041 [==============================] - 1s 352us/step - loss: 2.1022 - acc: 0.8681 - f1_m: 0.9284 - precision_m: 0.8681 - recall_m: 1.0000
# 27/27 [==============================] - 4s 139ms/step
# Epoch 1/3
# 3031/3031 [==============================] - 10s 3ms/step - loss: 2.1290 - acc: 0.8641 - f1_m: 0.9257 - precision_m: 0.8660 - recall_m: 0.9974
# Epoch 2/3
# 3031/3031 [==============================] - 1s 345us/step - loss: 2.1302 - acc: 0.8664 - f1_m: 0.9275 - precision_m: 0.8664 - recall_m: 1.0000
# Epoch 3/3
# 3031/3031 [==============================] - 1s 325us/step - loss: 2.1302 - acc: 0.8664 - f1_m: 0.9272 - precision_m: 0.8664 - recall_m: 1.0000
# 37/37 [==============================] - 4s 102ms/step
# Epoch 1/3
# 3040/3040 [==============================] - 10s 3ms/step - loss: 2.0656 - acc: 0.8668 - f1_m: 0.9260 - precision_m: 0.8699 - recall_m: 0.9939
# Epoch 2/3
# 3040/3040 [==============================] - 1s 353us/step - loss: 2.0767 - acc: 0.8697 - f1_m: 0.9294 - precision_m: 0.8697 - recall_m: 1.0000
# Epoch 3/3
# 3040/3040 [==============================] - 1s 359us/step - loss: 2.0767 - acc: 0.8697 - f1_m: 0.9292 - precision_m: 0.8697 - recall_m: 1.0000
# 28/28 [==============================] - 4s 137ms/step
# Epoch 1/3
# 3044/3044 [==============================] - 11s 3ms/step - loss: 2.1250 - acc: 0.8610 - f1_m: 0.9205 - precision_m: 0.8650 - recall_m: 0.9904
# Epoch 2/3
# 3044/3044 [==============================] - 1s 395us/step - loss: 2.1211 - acc: 0.8670 - f1_m: 0.9280 - precision_m: 0.8670 - recall_m: 1.0000
# Epoch 3/3
# 3044/3044 [==============================] - 1s 394us/step - loss: 2.1211 - acc: 0.8670 - f1_m: 0.9277 - precision_m: 0.8670 - recall_m: 1.0000
# 24/24 [==============================] - 4s 159ms/step
# Epoch 1/3
# 3045/3045 [==============================] - 10s 3ms/step - loss: 0.7199 - acc: 0.8108 - f1_m: 0.8861 - precision_m: 0.8696 - recall_m: 0.9218
# Epoch 2/3
# 3045/3045 [==============================] - 1s 367us/step - loss: 0.4305 - acc: 0.8631 - f1_m: 0.9248 - precision_m: 0.8683 - recall_m: 0.9921
# Epoch 3/3
# 3045/3045 [==============================] - 1s 350us/step - loss: 0.3955 - acc: 0.8657 - f1_m: 0.9269 - precision_m: 0.8673 - recall_m: 0.9976
# 23/23 [==============================] - 4s 165ms/step
# Epoch 1/3
# 3047/3047 [==============================] - 11s 3ms/step - loss: 2.1337 - acc: 0.8612 - f1_m: 0.9212 - precision_m: 0.8691 - recall_m: 0.9913
# Epoch 2/3
# 3047/3047 [==============================] - 1s 370us/step - loss: 2.1033 - acc: 0.8681 - f1_m: 0.9283 - precision_m: 0.8681 - recall_m: 1.0000
# Epoch 3/3
# 3047/3047 [==============================] - 1s 366us/step - loss: 2.1033 - acc: 0.8681 - f1_m: 0.9282 - precision_m: 0.8681 - recall_m: 1.0000
# 21/21 [==============================] - 4s 188ms/step
# Epoch 1/3
# 3045/3045 [==============================] - 11s 3ms/step - loss: 2.1452 - acc: 0.8611 - f1_m: 0.9228 - precision_m: 0.8677 - recall_m: 0.9930
# Epoch 2/3
# 3045/3045 [==============================] - 1s 366us/step - loss: 2.1204 - acc: 0.8670 - f1_m: 0.9275 - precision_m: 0.8670 - recall_m: 1.0000
# Epoch 3/3
# 3045/3045 [==============================] - 1s 376us/step - loss: 2.1204 - acc: 0.8670 - f1_m: 0.9276 - precision_m: 0.8670 - recall_m: 1.0000
# 23/23 [==============================] - 4s 172ms/step
# Epoch 1/3
# 3051/3051 [==============================] - 11s 3ms/step - loss: 2.2539 - acc: 0.8515 - f1_m: 0.9082 - precision_m: 0.8599 - recall_m: 0.9770
# Epoch 2/3
# 3051/3051 [==============================] - 1s 385us/step - loss: 2.1215 - acc: 0.8669 - f1_m: 0.9278 - precision_m: 0.8669 - recall_m: 1.0000
# Epoch 3/3
# 3051/3051 [==============================] - 1s 354us/step - loss: 2.1215 - acc: 0.8669 - f1_m: 0.9276 - precision_m: 0.8669 - recall_m: 1.0000
# 17/17 [==============================] - 4s 233ms/step
# Epoch 1/3
# 3046/3046 [==============================] - 11s 4ms/step - loss: 2.2555 - acc: 0.8575 - f1_m: 0.9179 - precision_m: 0.8670 - recall_m: 0.9898
# Epoch 2/3
# 3046/3046 [==============================] - 1s 368us/step - loss: 2.1302 - acc: 0.8664 - f1_m: 0.9275 - precision_m: 0.8664 - recall_m: 1.0000
# Epoch 3/3
# 3046/3046 [==============================] - 1s 364us/step - loss: 2.1302 - acc: 0.8664 - f1_m: 0.9274 - precision_m: 0.8664 - recall_m: 1.0000
# 22/22 [==============================] - 4s 182ms/step
# Epoch 1/3
# 3020/3020 [==============================] - 11s 4ms/step - loss: 2.1069 - acc: 0.8656 - f1_m: 0.9264 - precision_m: 0.8677 - recall_m: 0.9974
# Epoch 2/3
# 3020/3020 [==============================] - 1s 375us/step - loss: 2.1116 - acc: 0.8675 - f1_m: 0.9281 - precision_m: 0.8675 - recall_m: 1.0000
# Epoch 3/3
# 3020/3020 [==============================] - 1s 376us/step - loss: 2.1116 - acc: 0.8675 - f1_m: 0.9283 - precision_m: 0.8675 - recall_m: 1.0000
# 48/48 [==============================] - 4s 85ms/step
# Epoch 1/3
# 3049/3049 [==============================] - 11s 4ms/step - loss: 2.1119 - acc: 0.8652 - f1_m: 0.9260 - precision_m: 0.8678 - recall_m: 0.9965
# Epoch 2/3
# 3049/3049 [==============================] - 1s 384us/step - loss: 2.1176 - acc: 0.8672 - f1_m: 0.9279 - precision_m: 0.8672 - recall_m: 1.0000
# Epoch 3/3
# 3049/3049 [==============================] - 1s 370us/step - loss: 2.1176 - acc: 0.8672 - f1_m: 0.9278 - precision_m: 0.8672 - recall_m: 1.0000
# 19/19 [==============================] - 4s 216ms/step
# Epoch 1/3
# 3049/3049 [==============================] - 11s 4ms/step - loss: 2.1978 - acc: 0.8590 - f1_m: 0.9181 - precision_m: 0.8678 - recall_m: 0.9899
# Epoch 2/3
# 3049/3049 [==============================] - 1s 359us/step - loss: 2.1281 - acc: 0.8665 - f1_m: 0.9274 - precision_m: 0.8665 - recall_m: 1.0000
# Epoch 3/3
# 3049/3049 [==============================] - 1s 364us/step - loss: 2.1281 - acc: 0.8665 - f1_m: 0.9275 - precision_m: 0.8665 - recall_m: 1.0000
# 19/19 [==============================] - 4s 218ms/step
# Epoch 1/3
# 3015/3015 [==============================] - 11s 4ms/step - loss: 0.7154 - acc: 0.8143 - f1_m: 0.8896 - precision_m: 0.8705 - recall_m: 0.9245
# Epoch 2/3
# 3015/3015 [==============================] - 1s 380us/step - loss: 0.4459 - acc: 0.8577 - f1_m: 0.9218 - precision_m: 0.8703 - recall_m: 0.9821
# Epoch 3/3
# 3015/3015 [==============================] - 1s 365us/step - loss: 0.4145 - acc: 0.8590 - f1_m: 0.9224 - precision_m: 0.8687 - recall_m: 0.9870
# 53/53 [==============================] - 4s 80ms/step
# Epoch 1/3
# 3042/3042 [==============================] - 11s 4ms/step - loss: 2.1172 - acc: 0.8619 - f1_m: 0.9208 - precision_m: 0.8671 - recall_m: 0.9912
# Epoch 2/3
# 3042/3042 [==============================] - 1s 389us/step - loss: 2.1225 - acc: 0.8669 - f1_m: 0.9277 - precision_m: 0.8669 - recall_m: 1.0000
# Epoch 3/3
# 3042/3042 [==============================] - 1s 390us/step - loss: 2.1225 - acc: 0.8669 - f1_m: 0.9276 - precision_m: 0.8669 - recall_m: 1.0000
# 26/26 [==============================] - 4s 161ms/step
# Epoch 1/3
# 3052/3052 [==============================] - 11s 4ms/step - loss: 2.1805 - acc: 0.8588 - f1_m: 0.9192 - precision_m: 0.8620 - recall_m: 0.9903
# Epoch 2/3
# 3052/3052 [==============================] - 1s 374us/step - loss: 2.1208 - acc: 0.8670 - f1_m: 0.9276 - precision_m: 0.8670 - recall_m: 1.0000
# Epoch 3/3
# 3052/3052 [==============================] - 1s 361us/step - loss: 2.1208 - acc: 0.8670 - f1_m: 0.9277 - precision_m: 0.8670 - recall_m: 1.0000
# 16/16 [==============================] - 4s 264ms/step
# Epoch 1/3
# 3021/3021 [==============================] - 12s 4ms/step - loss: 2.1167 - acc: 0.8666 - f1_m: 0.9273 - precision_m: 0.8673 - recall_m: 0.9993
# Epoch 2/3
# 3021/3021 [==============================] - 1s 391us/step - loss: 2.1267 - acc: 0.8666 - f1_m: 0.9276 - precision_m: 0.8666 - recall_m: 1.0000
# Epoch 3/3
# 3021/3021 [==============================] - 1s 381us/step - loss: 2.1267 - acc: 0.8666 - f1_m: 0.9276 - precision_m: 0.8666 - recall_m: 1.0000
# 47/47 [==============================] - 4s 94ms/step
# Epoch 1/3
# 3030/3030 [==============================] - 12s 4ms/step - loss: 2.2562 - acc: 0.8525 - f1_m: 0.9136 - precision_m: 0.8563 - recall_m: 0.9832
# Epoch 2/3
# 3030/3030 [==============================] - 1s 368us/step - loss: 2.1467 - acc: 0.8653 - f1_m: 0.9268 - precision_m: 0.8653 - recall_m: 1.0000
# Epoch 3/3
# 3030/3030 [==============================] - 1s 388us/step - loss: 2.1467 - acc: 0.8653 - f1_m: 0.9265 - precision_m: 0.8653 - recall_m: 1.0000
# 38/38 [==============================] - 4s 115ms/step
# Epoch 1/3
# 3045/3045 [==============================] - 12s 4ms/step - loss: 4.2917 - acc: 0.7304 - f1_m: 0.7459 - precision_m: 0.6998 - recall_m: 0.8000
# Epoch 2/3
# 3045/3045 [==============================] - 1s 380us/step - loss: 2.0942 - acc: 0.8686 - f1_m: 0.9284 - precision_m: 0.8686 - recall_m: 1.0000
# Epoch 3/3
# 3045/3045 [==============================] - 1s 379us/step - loss: 2.0942 - acc: 0.8686 - f1_m: 0.9285 - precision_m: 0.8686 - recall_m: 1.0000
# 23/23 [==============================] - 4s 191ms/step
# Epoch 1/3
# 3045/3045 [==============================] - 12s 4ms/step - loss: 0.9382 - acc: 0.8016 - f1_m: 0.8780 - precision_m: 0.8620 - recall_m: 0.9067
# Epoch 2/3
# 3045/3045 [==============================] - 1s 411us/step - loss: 0.4282 - acc: 0.8598 - f1_m: 0.9230 - precision_m: 0.8700 - recall_m: 0.9866
# Epoch 3/3
# 3045/3045 [==============================] - 1s 415us/step - loss: 0.4072 - acc: 0.8680 - f1_m: 0.9283 - precision_m: 0.8691 - recall_m: 0.9985
# 23/23 [==============================] - 5s 196ms/step
# Epoch 1/3
# 3006/3006 [==============================] - 12s 4ms/step - loss: 2.1790 - acc: 0.8619 - f1_m: 0.9194 - precision_m: 0.8606 - recall_m: 0.9894
# Epoch 2/3
# 3006/3006 [==============================] - 1s 396us/step - loss: 2.0737 - acc: 0.8699 - f1_m: 0.9294 - precision_m: 0.8699 - recall_m: 1.0000
# Epoch 3/3
# 3006/3006 [==============================] - 1s 375us/step - loss: 2.0737 - acc: 0.8699 - f1_m: 0.9293 - precision_m: 0.8699 - recall_m: 1.0000
# 62/62 [==============================] - 4s 72ms/step
# Epoch 1/3
# 3006/3006 [==============================] - 12s 4ms/step - loss: 2.0835 - acc: 0.8623 - f1_m: 0.9232 - precision_m: 0.8693 - recall_m: 0.9895
# Epoch 2/3
# 3006/3006 [==============================] - 1s 399us/step - loss: 2.0843 - acc: 0.8693 - f1_m: 0.9292 - precision_m: 0.8693 - recall_m: 1.0000
# Epoch 3/3
# 3006/3006 [==============================] - 1s 416us/step - loss: 2.0843 - acc: 0.8693 - f1_m: 0.9293 - precision_m: 0.8693 - recall_m: 1.0000
# 62/62 [==============================] - 5s 74ms/step
# Epoch 1/3
# 3015/3015 [==============================] - 12s 4ms/step - loss: 2.2113 - acc: 0.8577 - f1_m: 0.9169 - precision_m: 0.8564 - recall_m: 0.9894
# Epoch 2/3
# 3015/3015 [==============================] - 1s 390us/step - loss: 2.1415 - acc: 0.8657 - f1_m: 0.9263 - precision_m: 0.8657 - recall_m: 1.0000
# Epoch 3/3
# 3015/3015 [==============================] - 1s 372us/step - loss: 2.1415 - acc: 0.8657 - f1_m: 0.9269 - precision_m: 0.8657 - recall_m: 1.0000
# 53/53 [==============================] - 5s 87ms/step
# Epoch 1/3
# 3032/3032 [==============================] - 12s 4ms/step - loss: 0.7310 - acc: 0.8186 - f1_m: 0.8914 - precision_m: 0.8560 - recall_m: 0.9352
# Epoch 2/3
# 3032/3032 [==============================] - 1s 392us/step - loss: 0.4199 - acc: 0.8628 - f1_m: 0.9255 - precision_m: 0.8666 - recall_m: 0.9952
# Epoch 3/3
# 3032/3032 [==============================] - 1s 380us/step - loss: 0.4003 - acc: 0.8671 - f1_m: 0.9279 - precision_m: 0.8670 - recall_m: 1.0000
# 36/36 [==============================] - 5s 129ms/step
# Epoch 1/3
# 3026/3026 [==============================] - 12s 4ms/step - loss: 2.1534 - acc: 0.8619 - f1_m: 0.9202 - precision_m: 0.8698 - recall_m: 0.9902
# Epoch 2/3
# 3026/3026 [==============================] - 1s 406us/step - loss: 2.1074 - acc: 0.8678 - f1_m: 0.9283 - precision_m: 0.8678 - recall_m: 1.0000
# Epoch 3/3
# 3026/3026 [==============================] - 1s 400us/step - loss: 2.1074 - acc: 0.8678 - f1_m: 0.9280 - precision_m: 0.8678 - recall_m: 1.0000
# 42/42 [==============================] - 5s 111ms/step
# Epoch 1/3
# 3000/3000 [==============================] - 13s 4ms/step - loss: 0.7310 - acc: 0.8230 - f1_m: 0.8979 - precision_m: 0.8650 - recall_m: 0.9427
# Epoch 2/3
# 3000/3000 [==============================] - 1s 404us/step - loss: 0.4308 - acc: 0.8620 - f1_m: 0.9246 - precision_m: 0.8653 - recall_m: 0.9954
# Epoch 3/3
# 3000/3000 [==============================] - 1s 387us/step - loss: 0.4130 - acc: 0.8653 - f1_m: 0.9265 - precision_m: 0.8657 - recall_m: 0.9997
# 68/68 [==============================] - 5s 69ms/step
# Epoch 1/3
# 3025/3025 [==============================] - 13s 4ms/step - loss: 0.9291 - acc: 0.7993 - f1_m: 0.8773 - precision_m: 0.8738 - recall_m: 0.9016
# Epoch 2/3
# 3025/3025 [==============================] - 1s 422us/step - loss: 0.4569 - acc: 0.8499 - f1_m: 0.9166 - precision_m: 0.8718 - recall_m: 0.9699
# Epoch 3/3
# 3025/3025 [==============================] - 1s 424us/step - loss: 0.4312 - acc: 0.8651 - f1_m: 0.9264 - precision_m: 0.8724 - recall_m: 0.9904
# 43/43 [==============================] - 5s 111ms/step
# Epoch 1/3
# 3030/3030 [==============================] - 13s 4ms/step - loss: 2.1577 - acc: 0.8597 - f1_m: 0.9218 - precision_m: 0.8656 - recall_m: 0.9927
# Epoch 2/3
# 3030/3030 [==============================] - 1s 404us/step - loss: 2.1414 - acc: 0.8657 - f1_m: 0.9268 - precision_m: 0.8657 - recall_m: 1.0000
# Epoch 3/3
# 3030/3030 [==============================] - 1s 408us/step - loss: 2.1414 - acc: 0.8657 - f1_m: 0.9270 - precision_m: 0.8657 - recall_m: 1.0000
# 38/38 [==============================] - 5s 126ms/step
# Epoch 1/3
# 3029/3029 [==============================] - 13s 4ms/step - loss: 2.3406 - acc: 0.8511 - f1_m: 0.9070 - precision_m: 0.8484 - recall_m: 0.9775
# Epoch 2/3
# 3029/3029 [==============================] - 1s 411us/step - loss: 2.1421 - acc: 0.8656 - f1_m: 0.9266 - precision_m: 0.8656 - recall_m: 1.0000
# Epoch 3/3
# 3029/3029 [==============================] - 1s 416us/step - loss: 2.1421 - acc: 0.8656 - f1_m: 0.9268 - precision_m: 0.8656 - recall_m: 1.0000
# 39/39 [==============================] - 5s 123ms/step
# Epoch 1/3
# 3040/3040 [==============================] - 13s 4ms/step - loss: 2.1396 - acc: 0.8658 - f1_m: 0.9270 - precision_m: 0.8658 - recall_m: 1.0000
# Epoch 2/3
# 3040/3040 [==============================] - 1s 430us/step - loss: 2.1396 - acc: 0.8658 - f1_m: 0.9270 - precision_m: 0.8658 - recall_m: 1.0000
# Epoch 3/3
# 3040/3040 [==============================] - 1s 426us/step - loss: 2.1396 - acc: 0.8658 - f1_m: 0.9272 - precision_m: 0.8658 - recall_m: 1.0000
# 28/28 [==============================] - 5s 174ms/step
# Epoch 1/3
# 3001/3001 [==============================] - 13s 4ms/step - loss: 2.2024 - acc: 0.8580 - f1_m: 0.9167 - precision_m: 0.8572 - recall_m: 0.9874
# Epoch 2/3
# 3001/3001 [==============================] - 1s 434us/step - loss: 2.1462 - acc: 0.8654 - f1_m: 0.9270 - precision_m: 0.8654 - recall_m: 1.0000
# Epoch 3/3
# 3001/3001 [==============================] - 1s 421us/step - loss: 2.1462 - acc: 0.8654 - f1_m: 0.9266 - precision_m: 0.8654 - recall_m: 1.0000
# 67/67 [==============================] - 5s 75ms/step
# Epoch 1/3
# 3040/3040 [==============================] - 13s 4ms/step - loss: 2.1734 - acc: 0.8609 - f1_m: 0.9209 - precision_m: 0.8691 - recall_m: 0.9909
# Epoch 2/3
# 3040/3040 [==============================] - 1s 423us/step - loss: 2.1029 - acc: 0.8681 - f1_m: 0.9285 - precision_m: 0.8681 - recall_m: 1.0000
# Epoch 3/3
# 3040/3040 [==============================] - 1s 447us/step - loss: 2.1029 - acc: 0.8681 - f1_m: 0.9283 - precision_m: 0.8681 - recall_m: 1.0000
# 28/28 [==============================] - 5s 180ms/step
# Epoch 1/3
# 3048/3048 [==============================] - 14s 4ms/step - loss: 0.7062 - acc: 0.8192 - f1_m: 0.8948 - precision_m: 0.8664 - recall_m: 0.9334
# Epoch 2/3
# 3048/3048 [==============================] - 1s 424us/step - loss: 0.4347 - acc: 0.8609 - f1_m: 0.9239 - precision_m: 0.8675 - recall_m: 0.9915
# Epoch 3/3
# 3048/3048 [==============================] - 1s 423us/step - loss: 0.4214 - acc: 0.8668 - f1_m: 0.9275 - precision_m: 0.8668 - recall_m: 1.0000
# 20/20 [==============================] - 5s 255ms/step
# Epoch 1/3
# 3044/3044 [==============================] - 14s 5ms/step - loss: 2.2370 - acc: 0.8581 - f1_m: 0.9173 - precision_m: 0.8571 - recall_m: 0.9895
# Epoch 2/3
# 3044/3044 [==============================] - 1s 435us/step - loss: 2.1263 - acc: 0.8666 - f1_m: 0.9274 - precision_m: 0.8666 - recall_m: 1.0000
# Epoch 3/3
# 3044/3044 [==============================] - 1s 428us/step - loss: 2.1263 - acc: 0.8666 - f1_m: 0.9276 - precision_m: 0.8666 - recall_m: 1.0000
# 24/24 [==============================] - 5s 213ms/step
# Epoch 1/3
# 3045/3045 [==============================] - 14s 5ms/step - loss: 0.6035 - acc: 0.8259 - f1_m: 0.9004 - precision_m: 0.8689 - recall_m: 0.9444
# Epoch 2/3
# 3045/3045 [==============================] - 1s 434us/step - loss: 0.4245 - acc: 0.8604 - f1_m: 0.9234 - precision_m: 0.8678 - recall_m: 0.9902
# Epoch 3/3
# 3045/3045 [==============================] - 1s 438us/step - loss: 0.4087 - acc: 0.8631 - f1_m: 0.9250 - precision_m: 0.8676 - recall_m: 0.9940
# 23/23 [==============================] - 5s 224ms/step
# Epoch 1/3
# 3050/3050 [==============================] - 14s 5ms/step - loss: 2.1768 - acc: 0.8577 - f1_m: 0.9183 - precision_m: 0.8637 - recall_m: 0.9899
# Epoch 2/3
# 3050/3050 [==============================] - 1s 435us/step - loss: 2.1326 - acc: 0.8662 - f1_m: 0.9273 - precision_m: 0.8662 - recall_m: 1.0000
# Epoch 3/3
# 3050/3050 [==============================] - 1s 423us/step - loss: 2.1326 - acc: 0.8662 - f1_m: 0.9270 - precision_m: 0.8662 - recall_m: 1.0000
# 18/18 [==============================] - 5s 288ms/step
# Epoch 1/3
# 3034/3034 [==============================] - 14s 5ms/step - loss: 2.1364 - acc: 0.8612 - f1_m: 0.9226 - precision_m: 0.8655 - recall_m: 0.9930
# Epoch 2/3
# 3034/3034 [==============================] - 1s 422us/step - loss: 2.1281 - acc: 0.8665 - f1_m: 0.9275 - precision_m: 0.8665 - recall_m: 1.0000
# Epoch 3/3
# 3034/3034 [==============================] - 1s 445us/step - loss: 2.1281 - acc: 0.8665 - f1_m: 0.9274 - precision_m: 0.8665 - recall_m: 1.0000
# 34/34 [==============================] - 5s 151ms/step
# Epoch 1/3
# 3054/3054 [==============================] - 14s 5ms/step - loss: 2.1506 - acc: 0.8621 - f1_m: 0.9215 - precision_m: 0.8690 - recall_m: 0.9915
# Epoch 2/3
# 3054/3054 [==============================] - 1s 414us/step - loss: 2.1194 - acc: 0.8671 - f1_m: 0.9278 - precision_m: 0.8671 - recall_m: 1.0000
# Epoch 3/3
# 3054/3054 [==============================] - 1s 425us/step - loss: 2.1194 - acc: 0.8671 - f1_m: 0.9277 - precision_m: 0.8671 - recall_m: 1.0000
# 14/14 [==============================] - 5s 375ms/step
# Epoch 1/3
# 3046/3046 [==============================] - 14s 5ms/step - loss: 2.2406 - acc: 0.8572 - f1_m: 0.9167 - precision_m: 0.8565 - recall_m: 0.9891
# Epoch 2/3
# 3046/3046 [==============================] - 1s 441us/step - loss: 2.1354 - acc: 0.8661 - f1_m: 0.9271 - precision_m: 0.8661 - recall_m: 1.0000
# Epoch 3/3
# 3046/3046 [==============================] - 1s 439us/step - loss: 2.1354 - acc: 0.8661 - f1_m: 0.9272 - precision_m: 0.8661 - recall_m: 1.0000
# 22/22 [==============================] - 5s 244ms/step
# Epoch 1/3
# 3046/3046 [==============================] - 14s 5ms/step - loss: 2.1394 - acc: 0.8601 - f1_m: 0.9206 - precision_m: 0.8687 - recall_m: 0.9909
# Epoch 2/3
# 3046/3046 [==============================] - 1s 424us/step - loss: 2.1040 - acc: 0.8680 - f1_m: 0.9283 - precision_m: 0.8680 - recall_m: 1.0000
# Epoch 3/3
# 3046/3046 [==============================] - 1s 430us/step - loss: 2.1040 - acc: 0.8680 - f1_m: 0.9281 - precision_m: 0.8680 - recall_m: 1.0000
# 22/22 [==============================] - 5s 244ms/step
# Epoch 1/3
# 3046/3046 [==============================] - 15s 5ms/step - loss: 2.0917 - acc: 0.8664 - f1_m: 0.9268 - precision_m: 0.8680 - recall_m: 0.9977
# Epoch 2/3
# 3046/3046 [==============================] - 1s 440us/step - loss: 2.1040 - acc: 0.8680 - f1_m: 0.9280 - precision_m: 0.8680 - recall_m: 1.0000
# Epoch 3/3
# 3046/3046 [==============================] - 1s 442us/step - loss: 2.1040 - acc: 0.8680 - f1_m: 0.9281 - precision_m: 0.8680 - recall_m: 1.0000
# 22/22 [==============================] - 5s 244ms/step
# Epoch 1/3
# 3036/3036 [==============================] - 14s 5ms/step - loss: 2.1570 - acc: 0.8594 - f1_m: 0.9184 - precision_m: 0.8590 - recall_m: 0.9887
# Epoch 2/3
# 3036/3036 [==============================] - 1s 431us/step - loss: 2.0952 - acc: 0.8686 - f1_m: 0.9285 - precision_m: 0.8686 - recall_m: 1.0000
# Epoch 3/3
# 3036/3036 [==============================] - 1s 434us/step - loss: 2.0952 - acc: 0.8686 - f1_m: 0.9285 - precision_m: 0.8686 - recall_m: 1.0000
# 32/32 [==============================] - 5s 169ms/step
# Epoch 1/3
# 3036/3036 [==============================] - 15s 5ms/step - loss: 2.1334 - acc: 0.8617 - f1_m: 0.9234 - precision_m: 0.8677 - recall_m: 0.9932
# Epoch 2/3
# 3036/3036 [==============================] - 1s 444us/step - loss: 2.1004 - acc: 0.8682 - f1_m: 0.9284 - precision_m: 0.8682 - recall_m: 1.0000
# Epoch 3/3
# 3036/3036 [==============================] - 1s 430us/step - loss: 2.1004 - acc: 0.8682 - f1_m: 0.9285 - precision_m: 0.8682 - recall_m: 1.0000
# 32/32 [==============================] - 5s 171ms/step
# Epoch 1/3
# 3011/3011 [==============================] - 15s 5ms/step - loss: 2.1239 - acc: 0.8665 - f1_m: 0.9271 - precision_m: 0.8668 - recall_m: 0.9996
# Epoch 2/3
# 3011/3011 [==============================] - 1s 431us/step - loss: 2.1232 - acc: 0.8668 - f1_m: 0.9276 - precision_m: 0.8668 - recall_m: 1.0000
# Epoch 3/3
# 3011/3011 [==============================] - 1s 428us/step - loss: 2.1232 - acc: 0.8668 - f1_m: 0.9275 - precision_m: 0.8668 - recall_m: 1.0000
# 57/57 [==============================] - 5s 96ms/step
# Epoch 1/3
# 3032/3032 [==============================] - 15s 5ms/step - loss: 0.8528 - acc: 0.8123 - f1_m: 0.8833 - precision_m: 0.8591 - recall_m: 0.9237
# Epoch 2/3
# 3032/3032 [==============================] - 1s 426us/step - loss: 0.4507 - acc: 0.8569 - f1_m: 0.9210 - precision_m: 0.8681 - recall_m: 0.9836
# Epoch 3/3
# 3032/3032 [==============================] - 1s 420us/step - loss: 0.4171 - acc: 0.8621 - f1_m: 0.9243 - precision_m: 0.8691 - recall_m: 0.9893
# 36/36 [==============================] - 5s 152ms/step
# Epoch 1/3
# 3045/3045 [==============================] - 15s 5ms/step - loss: 2.1346 - acc: 0.8621 - f1_m: 0.9235 - precision_m: 0.8665 - recall_m: 0.9940
# Epoch 2/3
# 3045/3045 [==============================] - 1s 447us/step - loss: 2.1257 - acc: 0.8667 - f1_m: 0.9269 - precision_m: 0.8667 - recall_m: 1.0000
# Epoch 3/3
# 3045/3045 [==============================] - 1s 433us/step - loss: 2.1257 - acc: 0.8667 - f1_m: 0.9276 - precision_m: 0.8667 - recall_m: 1.0000
# 23/23 [==============================] - 6s 245ms/step
# Epoch 1/3
# 3037/3037 [==============================] - 15s 5ms/step - loss: 2.2346 - acc: 0.8591 - f1_m: 0.9173 - precision_m: 0.8579 - recall_m: 0.9887
# Epoch 2/3
# 3037/3037 [==============================] - 1s 437us/step - loss: 2.1365 - acc: 0.8660 - f1_m: 0.9267 - precision_m: 0.8660 - recall_m: 1.0000
# Epoch 3/3
# 3037/3037 [==============================] - 1s 452us/step - loss: 2.1365 - acc: 0.8660 - f1_m: 0.9272 - precision_m: 0.8660 - recall_m: 1.0000
# 31/31 [==============================] - 6s 183ms/step
# Epoch 1/3
# 3027/3027 [==============================] - 15s 5ms/step - loss: 2.2589 - acc: 0.8570 - f1_m: 0.9167 - precision_m: 0.8560 - recall_m: 0.9894
# Epoch 2/3
# 3027/3027 [==============================] - 1s 454us/step - loss: 2.1436 - acc: 0.8655 - f1_m: 0.9268 - precision_m: 0.8655 - recall_m: 1.0000
# Epoch 3/3
# 3027/3027 [==============================] - 1s 447us/step - loss: 2.1436 - acc: 0.8655 - f1_m: 0.9265 - precision_m: 0.8655 - recall_m: 1.0000
# 41/41 [==============================] - 6s 140ms/step
# Epoch 1/3
# 3045/3045 [==============================] - 15s 5ms/step - loss: 2.1286 - acc: 0.8631 - f1_m: 0.9249 - precision_m: 0.8667 - recall_m: 0.9951
# Epoch 2/3
# 3045/3045 [==============================] - 1s 443us/step - loss: 2.1257 - acc: 0.8667 - f1_m: 0.9274 - precision_m: 0.8667 - recall_m: 1.0000
# Epoch 3/3
# 3045/3045 [==============================] - 1s 456us/step - loss: 2.1257 - acc: 0.8667 - f1_m: 0.9274 - precision_m: 0.8667 - recall_m: 1.0000
# 23/23 [==============================] - 6s 253ms/step
# 0.9201851690661483
